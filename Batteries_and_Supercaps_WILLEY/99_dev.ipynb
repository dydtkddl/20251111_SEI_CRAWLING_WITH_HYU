# %%
import os 
import pandas as pd 

import numpy as np 

pd.read_csv('./02_articles_metadata.csv')["access"].unique()
# array(['Full Access', 'Open Access', 'Free Access'], dtype=object)
# Out:
# array(['Full Access', 'Open Access', 'Free Access'], dtype=object)

# %%
DF = pd.read_csv('./02_articles_metadata.csv')
DF
# Out:
#                                                   title  \
# 0     Experimental Study of Capacity Fade in Large V...
# 1     Self-Sacrificial Copper Cluster-Catalyzed Oxyg...
# 2     Design Strategies for Electrolytes in Lithium ...
# 3     Entropy-Driven Design of Dual-Polymer Electrol...
# 4     Modification of the Solid Electrolyte Interpha...
# ...                                                 ...
# 1733  A New Rechargeable Seawater Desalination Batte...
# 1734  2D Titanium Carbide/Reduced Graphene Oxide Het...
# 1735  Batteries & Supercaps: The Future of Electroch...
# 1736  Artificial Composite Anode Comprising High-Cap...
# 1737  Valence-Tuned Lithium Titanate Nanopowder for ...
#
#                          doi                         href  \
# 0     10.1002/batt.202500450  /doi/10.1002/batt.202500450
# 1     10.1002/batt.202500588  /doi/10.1002/batt.202500588
# 2     10.1002/batt.202500550  /doi/10.1002/batt.202500550
# ...
